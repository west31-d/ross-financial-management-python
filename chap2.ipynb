# %%
#import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#we use yfinanace library 4 make example 
import yfinance as yf

# %%
#call balance_sheet 2 Apple > All examples are provided with Apple's stock data
ticker = yf.Ticker("AAPL")

#yearly
bs = ticker.balance_sheet

#quarterly
bs_quarterly = ticker.quarterly_balance_sheet

print(bs)

#check index
bs.index.tolist()
# Out:
#                                                     2025-09-30    2024-09-30  \
# Treasury Shares Number                                     NaN           NaN
# Ordinary Shares Number                            1.477326e+10  1.511679e+10
# Share Issued                                      1.477326e+10  1.511679e+10
# Net Debt                                          6.272300e+10  7.668600e+10
# Total Debt                                        9.865700e+10  1.066290e+11
# ...                                                        ...           ...
# Cash Cash Equivalents And Short Term Investments  5.469700e+10  6.517100e+10
# Other Short Term Investments                      1.876300e+10  3.522800e+10
# Cash And Cash Equivalents                         3.593400e+10  2.994300e+10
# Cash Equivalents                                  7.667000e+09  2.744000e+09
# Cash Financial                                    2.826700e+10  2.719900e+10
#
#                                                     2023-09-30    2022-09-30  \
# Treasury Shares Number                            0.000000e+00           NaN
# Ordinary Shares Number                            1.555006e+10  1.594342e+10
# Share Issued                                      1.555006e+10  1.594342e+10
# Net Debt                                          8.112300e+10  9.642300e+10
# Total Debt                                        1.110880e+11  1.324800e+11
# ...                                                        ...           ...
# Cash Cash Equivalents And Short Term Investments  6.155500e+10  4.830400e+10
# Other Short Term Investments                      3.159000e+10  2.465800e+10
# Cash And Cash Equivalents                         2.996500e+10  2.364600e+10
# Cash Equivalents                                  1.606000e+09  5.100000e+09
# Cash Financial                                    2.835900e+10  1.854600e+10
#
#                                                   2021-09-30
# Treasury Shares Number                                   NaN
# Ordinary Shares Number                                   NaN
# Share Issued                                             NaN
# Net Debt                                                 NaN
# Total Debt                                               NaN
# ...                                                      ...
# Cash Cash Equivalents And Short Term Investments         NaN
# Other Short Term Investments                             NaN
# Cash And Cash Equivalents                                NaN
# Cash Equivalents                                         NaN
# Cash Financial                                           NaN
#
# [69 rows x 5 columns]
# ['Treasury Shares Number',
#  'Ordinary Shares Number',
#  'Share Issued',
#  'Net Debt',
#  'Total Debt',
#  'Tangible Book Value',
#  'Invested Capital',
#  'Working Capital',
#  'Net Tangible Assets',
#  'Capital Lease Obligations',
#  'Common Stock Equity',
#  'Total Capitalization',
#  'Total Equity Gross Minority Interest',
#  'Stockholders Equity',
#  'Gains Losses Not Affecting Retained Earnings',
#  'Other Equity Adjustments',
#  'Retained Earnings',
#  'Capital Stock',
#  'Common Stock',
#  'Total Liabilities Net Minority Interest',
#  'Total Non Current Liabilities Net Minority Interest',
#  'Other Non Current Liabilities',
#  'Tradeand Other Payables Non Current',
#  'Long Term Debt And Capital Lease Obligation',
#  'Long Term Capital Lease Obligation',
#  'Long Term Debt',
#  'Current Liabilities',
#  'Other Current Liabilities',
#  'Current Deferred Liabilities',
#  'Current Deferred Revenue',
#  'Current Debt And Capital Lease Obligation',
#  'Current Capital Lease Obligation',
#  'Current Debt',
#  'Other Current Borrowings',
#  'Commercial Paper',
#  'Payables And Accrued Expenses',
#  'Current Accrued Expenses',
#  'Payables',
#  'Total Tax Payable',
#  'Income Tax Payable',
#  'Accounts Payable',
#  'Total Assets',
#  'Total Non Current Assets',
#  'Other Non Current Assets',
#  'Non Current Deferred Assets',
#  'Non Current Deferred Taxes Assets',
#  'Investments And Advances',
#  'Other Investments',
#  'Investmentin Financial Assets',
#  'Available For Sale Securities',
#  'Net PPE',
#  'Accumulated Depreciation',
#  'Gross PPE',
#  'Leases',
#  'Other Properties',
#  'Machinery Furniture Equipment',
#  'Land And Improvements',
#  'Properties',
#  'Current Assets',
#  'Other Current Assets',
#  'Inventory',
#  'Receivables',
#  'Other Receivables',
#  'Accounts Receivable',
#  'Cash Cash Equivalents And Short Term Investments',
#  'Other Short Term Investments',
#  'Cash And Cash Equivalents',
#  'Cash Equivalents',
#  'Cash Financial']

# %%
#net working capital = current asset - current liabilities

current_asset = bs.loc["Current Assets"]
current_liabilites = bs.loc["Current Liabilities"]

net_working_capital = current_asset - current_liabilites

print(net_working_capital)
# Out:
# 2025-09-30   -1.767400e+10
# 2024-09-30   -2.340500e+10
# 2023-09-30   -1.742000e+09
# 2022-09-30   -1.857700e+10
# 2021-09-30             NaN
# dtype: float64

# %%
# shareholder's equity = asset - liabilites
# asset - (equity + liabilites) = 0

total_asset = bs.loc["Total Assets"]
total_liabilites = bs.loc["Total Liabilities Net Minority Interest"]
total_equity = bs.loc["Total Equity Gross Minority Interest"]

check = total_asset - (total_equity + total_liabilites)

result = pd.DataFrame({
    "total asset": total_asset,
    "total equity": total_equity,
    "total liabilites": total_liabilites,
    "total equity + total liabilites" : total_liabilites + total_equity,
    "diff": check
    })

result
# Out:
#              total asset  total equity  total liabilites  \
# 2025-09-30  3.592410e+11  7.373300e+10      2.855080e+11
# 2024-09-30  3.649800e+11  5.695000e+10      3.080300e+11
# 2023-09-30  3.525830e+11  6.214600e+10      2.904370e+11
# 2022-09-30  3.527550e+11  5.067200e+10      3.020830e+11
# 2021-09-30           NaN           NaN               NaN
#
#             total equity + total liabilites  diff
# 2025-09-30                     3.592410e+11   0.0
# 2024-09-30                     3.649800e+11   0.0
# 2023-09-30                     3.525830e+11   0.0
# 2022-09-30                     3.527550e+11   0.0
# 2021-09-30                              NaN   NaN

# %%
# call income statement 4 Apple

#yearly
income_stmt = ticker.income_stmt

#quarterly
income_stmt_quarterly = ticker.quarterly_income_stmt

print(income_stmt)
income_stmt.index.tolist()
# Out:
#                                                       2025-09-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.560000e-01
# Normalized EBITDA                                   1.447480e+11
# Net Income From Continuing Operation Net Minori...  1.120100e+11
# Reconciled Depreciation                             1.169800e+10
# Reconciled Cost Of Revenue                          2.209600e+11
# EBITDA                                              1.447480e+11
# EBIT                                                1.330500e+11
# Net Interest Income                                          NaN
# Interest Expense                                             NaN
# Interest Income                                              NaN
# Normalized Income                                   1.120100e+11
# Net Income From Continuing And Discontinued Ope...  1.120100e+11
# Total Expenses                                      2.831110e+11
# Total Operating Income As Reported                  1.330500e+11
# Diluted Average Shares                              1.500470e+10
# Basic Average Shares                                1.494850e+10
# Diluted EPS                                         7.460000e+00
# Basic EPS                                           7.490000e+00
# Diluted NI Availto Com Stockholders                 1.120100e+11
# Net Income Common Stockholders                      1.120100e+11
# Net Income                                          1.120100e+11
# Net Income Including Noncontrolling Interests       1.120100e+11
# Net Income Continuous Operations                    1.120100e+11
# Tax Provision                                       2.071900e+10
# Pretax Income                                       1.327290e+11
# Other Income Expense                               -3.210000e+08
# Other Non Operating Income Expenses                -3.210000e+08
# Net Non Operating Interest Income Expense                    NaN
# Interest Expense Non Operating                               NaN
# Interest Income Non Operating                                NaN
# Operating Income                                    1.330500e+11
# Operating Expense                                   6.215100e+10
# Research And Development                            3.455000e+10
# Selling General And Administration                  2.760100e+10
# Gross Profit                                        1.952010e+11
# Cost Of Revenue                                     2.209600e+11
# Total Revenue                                       4.161610e+11
# Operating Revenue                                   4.161610e+11
#
#                                                       2024-09-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  2.410000e-01
# Normalized EBITDA                                   1.346610e+11
# Net Income From Continuing Operation Net Minori...  9.373600e+10
# Reconciled Depreciation                             1.144500e+10
# Reconciled Cost Of Revenue                          2.103520e+11
# EBITDA                                              1.346610e+11
# EBIT                                                1.232160e+11
# Net Interest Income                                          NaN
# Interest Expense                                             NaN
# Interest Income                                              NaN
# Normalized Income                                   9.373600e+10
# Net Income From Continuing And Discontinued Ope...  9.373600e+10
# Total Expenses                                      2.678190e+11
# Total Operating Income As Reported                  1.232160e+11
# Diluted Average Shares                              1.540810e+10
# Basic Average Shares                                1.534378e+10
# Diluted EPS                                         6.080000e+00
# Basic EPS                                           6.110000e+00
# Diluted NI Availto Com Stockholders                 9.373600e+10
# Net Income Common Stockholders                      9.373600e+10
# Net Income                                          9.373600e+10
# Net Income Including Noncontrolling Interests       9.373600e+10
# Net Income Continuous Operations                    9.373600e+10
# Tax Provision                                       2.974900e+10
# Pretax Income                                       1.234850e+11
# Other Income Expense                                2.690000e+08
# Other Non Operating Income Expenses                 2.690000e+08
# Net Non Operating Interest Income Expense                    NaN
# Interest Expense Non Operating                               NaN
# Interest Income Non Operating                                NaN
# Operating Income                                    1.232160e+11
# Operating Expense                                   5.746700e+10
# Research And Development                            3.137000e+10
# Selling General And Administration                  2.609700e+10
# Gross Profit                                        1.806830e+11
# Cost Of Revenue                                     2.103520e+11
# Total Revenue                                       3.910350e+11
# Operating Revenue                                   3.910350e+11
#
#                                                       2023-09-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.470000e-01
# Normalized EBITDA                                   1.258200e+11
# Net Income From Continuing Operation Net Minori...  9.699500e+10
# Reconciled Depreciation                             1.151900e+10
# Reconciled Cost Of Revenue                          2.141370e+11
# EBITDA                                              1.258200e+11
# EBIT                                                1.143010e+11
# Net Interest Income                                -1.830000e+08
# Interest Expense                                    3.933000e+09
# Interest Income                                     3.750000e+09
# Normalized Income                                   9.699500e+10
# Net Income From Continuing And Discontinued Ope...  9.699500e+10
# Total Expenses                                      2.689840e+11
# Total Operating Income As Reported                  1.143010e+11
# Diluted Average Shares                              1.581255e+10
# Basic Average Shares                                1.574423e+10
# Diluted EPS                                         6.130000e+00
# Basic EPS                                           6.160000e+00
# Diluted NI Availto Com Stockholders                 9.699500e+10
# Net Income Common Stockholders                      9.699500e+10
# Net Income                                          9.699500e+10
# Net Income Including Noncontrolling Interests       9.699500e+10
# Net Income Continuous Operations                    9.699500e+10
# Tax Provision                                       1.674100e+10
# Pretax Income                                       1.137360e+11
# Other Income Expense                               -5.650000e+08
# Other Non Operating Income Expenses                -5.650000e+08
# Net Non Operating Interest Income Expense          -1.830000e+08
# Interest Expense Non Operating                      3.933000e+09
# Interest Income Non Operating                       3.750000e+09
# Operating Income                                    1.143010e+11
# Operating Expense                                   5.484700e+10
# Research And Development                            2.991500e+10
# Selling General And Administration                  2.493200e+10
# Gross Profit                                        1.691480e+11
# Cost Of Revenue                                     2.141370e+11
# Total Revenue                                       3.832850e+11
# Operating Revenue                                   3.832850e+11
#
#                                                       2022-09-30    2021-09-30
# Tax Effect Of Unusual Items                         0.000000e+00           NaN
# Tax Rate For Calcs                                  1.620000e-01           NaN
# Normalized EBITDA                                   1.305410e+11           NaN
# Net Income From Continuing Operation Net Minori...  9.980300e+10           NaN
# Reconciled Depreciation                             1.110400e+10           NaN
# Reconciled Cost Of Revenue                          2.235460e+11           NaN
# EBITDA                                              1.305410e+11           NaN
# EBIT                                                1.194370e+11           NaN
# Net Interest Income                                -1.060000e+08  1.980000e+08
# Interest Expense                                    2.931000e+09  2.645000e+09
# Interest Income                                     2.825000e+09  2.843000e+09
# Normalized Income                                   9.980300e+10           NaN
# Net Income From Continuing And Discontinued Ope...  9.980300e+10           NaN
# Total Expenses                                      2.748910e+11           NaN
# Total Operating Income As Reported                  1.194370e+11           NaN
# Diluted Average Shares                              1.632582e+10           NaN
# Basic Average Shares                                1.621596e+10           NaN
# Diluted EPS                                         6.110000e+00           NaN
# Basic EPS                                           6.150000e+00           NaN
# Diluted NI Availto Com Stockholders                 9.980300e+10           NaN
# Net Income Common Stockholders                      9.980300e+10           NaN
# Net Income                                          9.980300e+10           NaN
# Net Income Including Noncontrolling Interests       9.980300e+10           NaN
# Net Income Continuous Operations                    9.980300e+10           NaN
# Tax Provision                                       1.930000e+10           NaN
# Pretax Income                                       1.191030e+11           NaN
# Other Income Expense                               -3.340000e+08           NaN
# Other Non Operating Income Expenses                -3.340000e+08           NaN
# Net Non Operating Interest Income Expense          -1.060000e+08  1.980000e+08
# Interest Expense Non Operating                      2.931000e+09  2.645000e+09
# Interest Income Non Operating                       2.825000e+09  2.843000e+09
# Operating Income                                    1.194370e+11           NaN
# Operating Expense                                   5.134500e+10           NaN
# Research And Development                            2.625100e+10           NaN
# Selling General And Administration                  2.509400e+10           NaN
# Gross Profit                                        1.707820e+11           NaN
# Cost Of Revenue                                     2.235460e+11           NaN
# Total Revenue                                       3.943280e+11           NaN
# Operating Revenue                                   3.943280e+11           NaN
# ['Tax Effect Of Unusual Items',
#  'Tax Rate For Calcs',
#  'Normalized EBITDA',
#  'Net Income From Continuing Operation Net Minority Interest',
#  'Reconciled Depreciation',
#  'Reconciled Cost Of Revenue',
#  'EBITDA',
#  'EBIT',
#  'Net Interest Income',
#  'Interest Expense',
#  'Interest Income',
#  'Normalized Income',
#  'Net Income From Continuing And Discontinued Operation',
#  'Total Expenses',
#  'Total Operating Income As Reported',
#  'Diluted Average Shares',
#  'Basic Average Shares',
#  'Diluted EPS',
#  'Basic EPS',
#  'Diluted NI Availto Com Stockholders',
#  'Net Income Common Stockholders',
#  'Net Income',
#  'Net Income Including Noncontrolling Interests',
#  'Net Income Continuous Operations',
#  'Tax Provision',
#  'Pretax Income',
#  'Other Income Expense',
#  'Other Non Operating Income Expenses',
#  'Net Non Operating Interest Income Expense',
#  'Interest Expense Non Operating',
#  'Interest Income Non Operating',
#  'Operating Income',
#  'Operating Expense',
#  'Research And Development',
#  'Selling General And Administration',
#  'Gross Profit',
#  'Cost Of Revenue',
#  'Total Revenue',
#  'Operating Revenue']

# %%
#revenues - expenses = income

total_revenues = income_stmt.loc["Total Revenue"]
total_expenses = income_stmt.loc["Total Expenses"] + income_stmt.loc["Tax Provision"] 
    # There's no built-in "total expenses" field, so I added the tax provision manually
net_income = income_stmt.loc["Net Income"]

check = total_revenues - total_expenses

result = pd.DataFrame({'revenues': total_revenues,
                       'expenses' : total_expenses,
                       'income': net_income,
                       'diff' : check,
                       })

result
# Out:
#                 revenues      expenses        income          diff
# 2025-09-30  4.161610e+11  3.038300e+11  1.120100e+11  1.123310e+11
# 2024-09-30  3.910350e+11  2.975680e+11  9.373600e+10  9.346700e+10
# 2023-09-30  3.832850e+11  2.857250e+11  9.699500e+10  9.756000e+10
# 2022-09-30  3.943280e+11  2.941910e+11  9.980300e+10  1.001370e+11
# 2021-09-30           NaN           NaN           NaN           NaN

# %%
#simple income statement

# dividends is on cashflow, not income statement so I called cashflow
cashflow = ticker.cashflow

# and addition to retained Earnings is a cumulative balance, so the increase is computed
# by subtracting the prior period's balance from the current period's.
 
retained_earnings = bs.loc["Retained Earnings"]
addition_to_retained_earnings = retained_earnings - retained_earnings.shift(-1)


simple_income_statement = pd.DataFrame({
    "net sales" : income_stmt.loc["Total Revenue"],
    "cost of goods sold" : income_stmt.loc["Cost Of Revenue"],
    "depreciation" : income_stmt.loc["Reconciled Depreciation"],
    "EBIT" : income_stmt.loc["EBIT"],
    "interest paid" : income_stmt.loc["Interest Expense"],
    "EBT" : income_stmt.loc["Pretax Income"],
    "taxes" : income_stmt.loc["Tax Provision"],
    "net income" : income_stmt.loc["Net Income"],
    "dividends" : cashflow.loc["Cash Dividends Paid"],
    "addition to retained earnings" : addition_to_retained_earnings
})

check = (simple_income_statement["net income"] 
         + simple_income_statement["dividends"]   
         - simple_income_statement["addition to retained earnings"])

simple_income_statement["check"] = check
simple_income_statement

# A small gap can remain due to share buybacks and other equity adjustments
# (e.g. stock-based compensation) that aren't fully captured here.
# Out:
#                net sales  cost of goods sold  depreciation          EBIT  \
# 2025-09-30  4.161610e+11        2.209600e+11  1.169800e+10  1.330500e+11
# 2024-09-30  3.910350e+11        2.103520e+11  1.144500e+10  1.232160e+11
# 2023-09-30  3.832850e+11        2.141370e+11  1.151900e+10  1.143010e+11
# 2022-09-30  3.943280e+11        2.235460e+11  1.110400e+10  1.194370e+11
# 2021-09-30           NaN                 NaN           NaN           NaN
#
#             interest paid           EBT         taxes    net income  \
# 2025-09-30            NaN  1.327290e+11  2.071900e+10  1.120100e+11
# 2024-09-30            NaN  1.234850e+11  2.974900e+10  9.373600e+10
# 2023-09-30   3.933000e+09  1.137360e+11  1.674100e+10  9.699500e+10
# 2022-09-30   2.931000e+09  1.191030e+11  1.930000e+10  9.980300e+10
# 2021-09-30   2.645000e+09           NaN           NaN           NaN
#
#                dividends  addition to retained earnings         check
# 2025-09-30 -1.542100e+10                   4.890000e+09  9.169900e+10
# 2024-09-30 -1.523400e+10                  -1.894000e+10  9.744200e+10
# 2023-09-30 -1.502500e+10                   2.854000e+09  7.911600e+10
# 2022-09-30 -1.484100e+10                            NaN           NaN
# 2021-09-30           NaN                            NaN           NaN

# %%
#marginal tax rate calculator
tax_brackets = [
        (9875, 0.10),
        (40125, 0.12),
        (85525, 0.22),
        (163300, 0.24),
        (207350, 0.32),
        (518400, 0.35),
        (float("inf"), 0.37)
    ]

taxable_income = int(input())

def marginal_tax_rate(taxable_income):
    tax = 0
    lower = 0
    marginal_rate = None

    for upper, rate in tax_brackets:
        if taxable_income > lower:
            taxed_amount = min(taxable_income, upper) - lower
            tax += taxed_amount * rate
            marginal_rate = rate

        lower = upper
        if taxable_income <= upper:
            break

    average_rate = tax / taxable_income if taxable_income > 0 else 0
    
    return tax, marginal_rate, average_rate

tax, marginal_rate, average_rate = marginal_tax_rate(taxable_income)

print(taxable_income)
print("tax: ", tax)
print("marginal_rate: ", marginal_rate)
print("average_rate: ", average_rate)
# Out:
# 2011502
# tax:  708682.74
# marginal_rate:  0.37
# average_rate:  0.3523152052545809

# %%
#Cashflow
#cash flow from assets(CFFA) = cash flow from creditors(CFTC) + cash flow to stockholders(CFTS)

#CFFA is operating cash flow(OCF) - net capital spending(NCS) - net working captial(NWC)

#OCF is EBIT + Depreciation - Taxes
ocf = income_stmt.loc["EBIT"] + income_stmt.loc["Reconciled Depreciation"] - income_stmt.loc["Tax Provision"]

#NCS is Ending Net Fixed Assets - Beginning Net Fixed Assets + Depreciation
ncs = bs.loc["Net PPE"] - bs.loc["Net PPE"].shift(-1) + income_stmt.loc["Reconciled Depreciation"]

ncs
# Out:
# 2025-09-30    1.585200e+10
# 2024-09-30    1.341000e+10
# 2023-09-30    1.311700e+10
# 2022-09-30             NaN
# 2021-09-30             NaN
# dtype: float64
